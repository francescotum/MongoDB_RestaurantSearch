# %%
from pymongo import MongoClient

client = MongoClient("localhost", 27017)

# Assign the database to a variable
db = client.NonRelProj 

# Take the collection "Reviews"
reviews = db.Reviews

# Take the collection "MetaData"
meta = db.MetaData

# %% [markdown]
# # Convert hours <br>
# Convert opening and closing times
#
# The following is a document of the collection MetaData (the one containing the data of businesses). We want to convert the format of 'hour'
# ```python
# # Example data
# restaurant_data = {
#     "name": "Kraken Coffee Kahului",
#     "category": "Restaurant",
#     "hours": [['Thursday', '11AM–8PM'], ['Friday', '11AM–8PM'],
#     ['Saturday', '11AM–8PM'], ['Sunday', 'Closed'], ['Monday', '11AM–8PM'],
#     ['Tuesday', '11AM–8PM'], ['Wednesday', '11AM–8PM']],
#     "location": {"type": "Point", "coordinates": [-156.4506136, 20.8882377]}
# }
# ```
#
# The purpose is to have a more structured format for 'hour', we want each document to explicit its opening and closing time for each day and obtain in the end something like this:
#
# [{'day': 'Thursday', 'open_time': '11:00', 'close_time': '20:00'}, {'day': 'Friday', 'open_time': '11:00', 'close_time': '20:00'}, {'day': 'Saturday', 'open_time': '11:00', 'close_time': '20:00'}, {'day': 'Sunday', 'open_time': '99:99', 'close_time': '99:99'}, {'day': 'Monday', 'open_time': '11:00', 'close_time': '20:00'}, {'day': 'Tuesday', 'open_time': '11:00', 'close_time': '20:00'}, {'day': 'Wednesday', 'open_time': '11:00', 'close_time': '20:00'}]

# %%
from datetime import datetime

def convert_hours(hours_list):
    if not hours_list or not isinstance(hours_list, list):
        return []  # Return empty list if invalid

    formatted_hours = []
    
    for entry in hours_list:
        if isinstance(entry, dict):  
            # Already formatted, keep as is
            formatted_hours.append(entry)  
            continue  

        if not isinstance(entry, list) or len(entry) != 2:
            print(f"Skipping invalid entry: {entry}")  
            continue  

        day, time_range = entry

        if not isinstance(day, str) or not \
            isinstance(time_range, str):
            print(f"Skipping invalid data format: {entry}")  
            continue  

        # Handle 'Closed' case 
        # -> Assign '99:99' to indicate closure
        if time_range.lower() == "closed":
            formatted_hours.append({
                "day": day,
                "open_time": "99:99",
                "close_time": "99:99"
            })
            continue  

        # Handle 'Open 24 hours' case
        if "24 hours" in time_range.lower():
            formatted_hours.append({
                "day": day,
                "open_time": "00:00",
                "close_time": "23:59"
            })
            continue  

        try:
            # Split by en-dash
            open_time, close_time = time_range.split("–")  
        except ValueError:
            print(f"Skipping invalid time format: {entry}")  
            continue  

        # Ensure open_time gets the same AM/PM 
        # indication as close_time if missing
        if "AM" in close_time or "PM" in close_time:
            if not ("AM" in open_time or "PM" in open_time):
                open_time += "AM" \
                    if "AM" in close_time else "PM"

        # Convert open time
        try:
            if ":" in open_time:
                open_time = datetime.strptime(
                    open_time.strip(), "%I:%M%p").strftime(
                        "%H:%M")
            else:
                open_time = datetime.strptime(
                    open_time.strip(), "%I%p").strftime(
                        "%H:%M")
        except ValueError:
            print(f"Skipping invalid open_time: \
                  {open_time} (close_time is {close_time})")  
            continue  

        # Convert close time
        try:
            if ":" in close_time:
                close_time = datetime.strptime(
                    close_time.strip(), "%I:%M%p").strftime(
                        "%H:%M")
            else:
                close_time = datetime.strptime(
                    close_time.strip(), "%I%p").strftime(
                        "%H:%M")
        except ValueError:
            print(f"Skipping invalid close_time: \
                  {close_time} (open_time is {open_time})")  
            continue  

        formatted_hours.append({
            "day": day,
            "open_time": open_time,
            "close_time": close_time
        })

    return formatted_hours





# Example data with 'hours' in a format like the raw one, let's see the output we get after the conversion
restaurant_data = {
    "name": "Kraken Coffee Kahului",
    "category": "Restaurant",
    "hours": [['Thursday', '11AM–8PM'], 
              ['Friday', '11AM–8PM'], 
              ['Saturday', '11AM–8PM'], 
              ['Sunday', 'Closed'], 
              ['Monday', '11AM–8PM'], 
              ['Tuesday', '11AM–8PM'], 
              ['Wednesday', '11AM–8PM']],
    "location": {"type": "Point", "coordinates": 
                 [-156.4506136, 20.8882377]}
}

# Apply the function
formatted_hours = convert_hours(restaurant_data["hours"])

# Print the output
print(formatted_hours)
# Out:
# [{'day': 'Thursday', 'open_time': '11:00', 'close_time': '20:00'}, {'day': 'Friday', 'open_time': '11:00', 'close_time': '20:00'}, {'day': 'Saturday', 'open_time': '11:00', 'close_time': '20:00'}, {'day': 'Sunday', 'open_time': '99:99', 'close_time': '99:99'}, {'day': 'Monday', 'open_time': '11:00', 'close_time': '20:00'}, {'day': 'Tuesday', 'open_time': '11:00', 'close_time': '20:00'}, {'day': 'Wednesday', 'open_time': '11:00', 'close_time': '20:00'}]

# %% [markdown]
# Let's convert the format of hours for all documents

# %%
# Initialize a counter for documents not updated
not_updated_count = 0

# Process all documents with the "hours" field
for doc in meta.find({"hours": {"$exists": True}}):
    try:
        # Transform hours
        updated_hours = convert_hours(doc["hours"])  
        
        if updated_hours:
            # Only update if we have valid hours  
            meta.update_one({"_id": doc["_id"]}, 
                            {"$set": {"hours": updated_hours}
                             })
            #print(f"Updated document ID: {doc['_id']}")
        else:
            # Increment the counter if hours 
            # are empty or invalid
            not_updated_count += 1
            print(f"Skipping update for document ID \
                  {doc['_id']} due to empty or \
                    invalid hours.")

    except Exception as e:
        print(f"Error processing document ID\
               {doc['_id']}: {e}")
        # Increment count on exception
        not_updated_count += 1  

print(f"All documents processed. {not_updated_count}\
       documents were not updated.")
# Out:
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bcf12 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bcf14 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bcf68 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bcf6a due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd054 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd106 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd231 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd237 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd277 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd2e7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd2f7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd330 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd334 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd34a due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd3c5 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd3e9 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd41e due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd500 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd551 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd568 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd59b due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd5a6 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd622 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd662 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd680 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd682 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd68e due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd7c8 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd808 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd826 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd83e due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd867 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd8ec due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bd931 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bda23 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bda26 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdaae due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdaf0 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdb2d due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdb7d due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdb80 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdbb7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdbfd due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdc4e due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdc7f due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdc80 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdcbb due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdcbc due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdcd5 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdd02 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdd0d due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bdd7f due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bddae due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bde1e due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ac8c4ae1c3ac1bde42 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bdf79 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bdfb6 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be00c due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be05e due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be06f due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be0d9 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be142 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be1e9 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be2bd due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be2f7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be2fd due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be300 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be35e due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be3c1 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be482 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be5a2 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be5b2 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be5b7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be5c7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be5d3 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be5db due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be5e8 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be5f6 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be60c due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be694 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be7a3 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be7b3 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be881 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be8a5 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be8be due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be8c7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be95b due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be962 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be994 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1be9fd due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bea26 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bea45 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bea92 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1beb52 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1beba0 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1beba4 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bebf2 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bec14 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bed97 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bed9b due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bedb7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bedca due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1beddd due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bee45 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1beec7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bef77 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1befa7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1befab due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf000 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf002 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf04a due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf051 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf0c9 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf108 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf158 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf26e due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf2c7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf30e due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf313 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf3e7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf3fc due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf4a8 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf544 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf591 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ad8c4ae1c3ac1bf593 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bf5fc due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bf62e due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bf663 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bf665 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bf666 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bf66d due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bf6c8 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bf766 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bf8b1 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bf8ea due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bf931 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bf968 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bf9e9 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bfa7d due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bfb82 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bfc1c due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bfc59 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bfc60 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bfdda due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bfe39 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bfe69 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bfef7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bff1b due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bff1c due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bff27 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bff4a due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1bff55 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c00a4 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c00d6 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c0129 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c024d due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c0268 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c0270 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c02b5 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c033c due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c0366 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c0384 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c040d due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c0418 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c044a due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c048b due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c04af due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c04c2 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c04e2 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c056f due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c058b due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c05c6 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c05fa due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c0655 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c0665 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c0677 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c077b due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c07ae due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c07cb due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c0806 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c084a due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c08d2 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c0901 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c0909 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751ae8c4ae1c3ac1c090d due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0976 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c099c due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c09a3 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c09a4 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c09f5 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0a65 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0b7f due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0bd6 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0c10 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0c7e due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0d48 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0d4e due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0d54 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0e97 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0f1b due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0f89 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0fa5 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0fcb due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c0fd3 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1062 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1083 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c113a due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c113b due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c115d due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1239 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1306 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1336 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1363 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1506 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c154c due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1601 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c165f due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c16c1 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c179b due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1825 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c18c5 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c18f5 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c194d due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1958 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1977 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c19b4 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1a16 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1a9a due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1ae3 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1b33 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1b34 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1bbb due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1bcb due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1c55 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1c56 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1c66 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1c74 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1c75 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1cc3 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1cd3 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751af8c4ae1c3ac1c1ce6 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c1d76 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c1d95 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c1ebe due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c1ed7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c1f33 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c1f37 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c1f46 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c1f61 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c1fa7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c1fad due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c203d due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c204d due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c205a due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c206a due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c2075 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c20b0 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c20f7 due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c213d due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c214b due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c221a due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c228b due to empty or                     invalid hours.
# Skipping update for document ID                   67c751b08c4ae1c3ac1c22d3 due to empty or                     invalid hours.
# All documents processed. 263       documents were not updated.

# %% [markdown]
# Show a restaurant with the new **'hour'** format

# %%
example = meta.find_one({})

# Print the document if found
if example:
    from pprint import pprint  # Pretty print for better readability
    pprint(example)
# Out:
# {'MISC': {'Accessibility': ['Wheelchair accessible entrance'],
#           'Amenities': ['Good for kids'],
#           'Atmosphere': ['Casual'],
#           'Crowd': ['Groups', 'Tourists'],
#           'Offerings': ['Comfort food', 'Quick bite'],
#           'Payments': ['NFC mobile payments'],
#           'Popular for': ['Lunch', 'Solo dining'],
#           'Service options': ['Outdoor seating', 'Takeout', 'Delivery']},
#  '_id': ObjectId('67c751ac8c4ae1c3ac1bceda'),
#  'address': 'Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762',
#  'avg_rating': 4.4,
#  'category': ['Restaurant'],
#  'description': None,
#  'gmap_id': '0x7c00456eecad3111:0x8217f9600c51f33',
#  'hours': [{'close_time': '20:00', 'day': 'Thursday', 'open_time': '11:00'},
#            {'close_time': '20:00', 'day': 'Friday', 'open_time': '11:00'},
#            {'close_time': '20:00', 'day': 'Saturday', 'open_time': '11:00'},
#            {'close_time': '99:99', 'day': 'Sunday', 'open_time': '99:99'},
#            {'close_time': '20:00', 'day': 'Monday', 'open_time': '11:00'},
#            {'close_time': '20:00', 'day': 'Tuesday', 'open_time': '11:00'},
#            {'close_time': '20:00', 'day': 'Wednesday', 'open_time': '11:00'}],
#  'latitude': 21.637795699999998,
#  'location': {'coordinates': [-157.9207142, 21.637795699999998],
#               'type': 'Point'},
#  'longitude': -157.9207142,
#  'name': 'Hale Pops',
#  'num_of_reviews': 18,
#  'price': None,
#  'state': 'Closed ⋅ Opens 11AM'}

# %% [markdown]
# In order to ease the filtering of restaurants based on time (hour of the day) let's convert all the opening hours in seconds from midnight.

# %%
def time_to_seconds(time_str):
    # If it's already an integer, return as is
    if isinstance(time_str, int):  
        return time_str
    
    # Handle unexpected types
    if not isinstance(time_str, str):  
        return None  

    # Split the time string by ":"
    time_parts = time_str.split(":")
    
    # Check if the string is correctly 
    # formatted (should have exactly two parts)
    if len(time_parts) == 2:
        try:
            # Convert hours and minutes to integers
            hours = int(time_parts[0])
            minutes = int(time_parts[1])
            
            # Calculate total seconds from midnight
            return hours * 3600 + minutes * 60
        except ValueError:
            # Handle case where hours or 
            # minutes are not integers
            return None  
    else:
        # Handle invalid time format (not "HH:MM")
        return None  
    

print(time_to_seconds("23:30"))  # Should print 84600 
print(time_to_seconds("10:45"))  # Should print 38700 
print(time_to_seconds("14:47"))  # Should print 53220
# Out:
# 84600
# 38700
# 53220

# %% [markdown]
# Loop for converting opening and closing time of all restaurants:

# %%
# Find all documents
for doc in meta.find({}):
    # Get the 'hours' field safely  
    hours_list = doc.get("hours")

    # Skip if 'hours' is missing or not a list
    if not isinstance(hours_list, list):  
        continue

    updated_hours = []

    for entry in hours_list:
        # Ensure each entry is a dictionary  
        if not isinstance(entry, dict):  
            continue

        updated_hours.append({
            "day": entry.get("day", ""),  
            "open_time": time_to_seconds(
                entry.get("open_time", "99:99")),  
            "close_time": time_to_seconds(
                entry.get("close_time", "99:99"))  
        })

    if updated_hours:
        meta.update_one({"_id": doc["_id"]}, 
                        {"$set": {"hours": updated_hours}})

print("All documents updated successfully!")
# Out:
# All documents updated successfully!

# %%
example = meta.find_one({})

# Print the document if found
if example:
    from pprint import pprint  # Pretty print for better readability
    pprint(example)
# Out:
# {'MISC': {'Accessibility': ['Wheelchair accessible entrance'],
#           'Amenities': ['Good for kids'],
#           'Atmosphere': ['Casual'],
#           'Crowd': ['Groups', 'Tourists'],
#           'Offerings': ['Comfort food', 'Quick bite'],
#           'Payments': ['NFC mobile payments'],
#           'Popular for': ['Lunch', 'Solo dining'],
#           'Service options': ['Outdoor seating', 'Takeout', 'Delivery']},
#  '_id': ObjectId('67c751ac8c4ae1c3ac1bceda'),
#  'address': 'Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762',
#  'avg_rating': 4.4,
#  'category': ['Restaurant'],
#  'description': None,
#  'gmap_id': '0x7c00456eecad3111:0x8217f9600c51f33',
#  'hours': [{'close_time': 72000, 'day': 'Thursday', 'open_time': 39600},
#            {'close_time': 72000, 'day': 'Friday', 'open_time': 39600},
#            {'close_time': 72000, 'day': 'Saturday', 'open_time': 39600},
#            {'close_time': 362340, 'day': 'Sunday', 'open_time': 362340},
#            {'close_time': 72000, 'day': 'Monday', 'open_time': 39600},
#            {'close_time': 72000, 'day': 'Tuesday', 'open_time': 39600},
#            {'close_time': 72000, 'day': 'Wednesday', 'open_time': 39600}],
#  'latitude': 21.637795699999998,
#  'location': {'coordinates': [-157.9207142, 21.637795699999998],
#               'type': 'Point'},
#  'longitude': -157.9207142,
#  'name': 'Hale Pops',
#  'num_of_reviews': 18,
#  'price': None,
#  'state': 'Closed ⋅ Opens 11AM'}
